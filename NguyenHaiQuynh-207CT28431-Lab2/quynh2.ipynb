# %%
import pandas as pd
import numpy as np

df = pd.read_csv("processed_dulieuxettuyendaihoc.csv",index_col="STT")
print(df.head(10))
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.01
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  5.07
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  6.04
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  6.2  ...  6.21  5.20  6.88
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  5.5  ...  6.50  6.36  6.99
# 6    9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  7.8  ...  7.96  8.54  7.38
# 7    2.8  3.9  5.5  6.9  5.0  7.3  4.6  5.2  4.4  6.7  ...  4.90  5.60  6.01
# 8    8.3  6.0  7.6  5.1  7.5  4.7  5.8  7.2  6.7  6.3  ...  6.80  6.87  7.03
# 9    6.5  6.3  7.6  6.0  5.5  7.1  6.3  5.0  7.3  6.8  ...  6.23  6.72  7.56
# 10   7.3  5.9  4.7  7.1  6.7  7.9  6.7  7.7  8.0  6.8  ...  6.80  7.25  7.03
#
#      XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# STT
# ...

# %%
df.sort_values(by=["GT","DH2"])
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 96   8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  6.8  ...  7.43  7.42  6.83
# 26   3.6  5.8  6.9  6.1  5.5  7.2  5.5  4.3  4.2  5.4  ...  5.40  5.20  5.09
# 25   2.4  4.1  3.6  5.5  5.9  5.6  4.9  4.2  3.3  5.7  ...  4.45  4.88  5.41
# 47   6.7  6.8  6.4  5.9  5.6  6.4  8.0  6.8  6.6  6.9  ...  6.49  6.51  6.16
# 14   4.9  5.4  5.0  5.0  5.8  7.0  4.2  5.8  4.5  4.5  ...  5.38  5.51  6.26
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 69   7.3  6.4  6.9  7.5  6.2  8.4  7.6  8.1  8.1  7.0  ...  7.19  7.70  8.00
# 12   7.9  7.0  9.1  8.6  6.1  7.0  5.6  9.0  8.2  7.1  ...  7.43  7.72  7.49
# 48   7.9  7.6  8.4  8.6  6.2  7.5  8.7  7.7  7.3  7.5  ...  7.67  7.49  7.11
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  6.04
# ...

# %%
def get_mean(scores):
    return sum(scores)/len(scores)

# %%
#get the mean score for each subject
result = df["DH1"].sum()
print("\nThe result of applying the function on the dataframe:\n")
print(result)
# Out:
# The result of applying the function on the dataframe:
#
# 374.0

# %%
def Q1(g):
    return np.percentile(g,25)

# %%
def Q2(g):
    return np.percentile(g,25)

# %%
def Q3(g):
    return np.percentile(g,25)

# %%
def std(g):
    return np.std(g)

# %%
pd.pivot_table(data=df,index = 'KT',values = 'DH1',aggfunc=['sum','mean','min','max', std,Q1,Q2,Q3])
# Out:
#        sum      mean   min   max       std      Q1      Q2      Q3
#        DH1       DH1   DH1   DH1       DH1     DH1     DH1     DH1
# KT
# A   163.50  3.336735  1.00  6.50  1.261226  2.2500  2.2500  2.2500
# A1   17.50  2.916667  2.00  4.25  0.786165  2.1875  2.1875  2.1875
# B    29.50  3.277778  1.75  4.50  0.776785  3.2500  3.2500  3.2500
# C    79.25  5.660714  4.75  7.00  0.782665  5.0625  5.0625  5.0625
# D1   84.25  3.829545  1.25  6.75  1.338644  3.0000  3.0000  3.0000

# %%
pd.pivot_table(data=df,index = ['KT','KV'],values = 'DH1',aggfunc=['sum','mean','min','max', std,Q1,Q2,Q3])
# Out:
#           sum      mean   min   max       std      Q1      Q2      Q3
#           DH1       DH1   DH1   DH1       DH1     DH1     DH1     DH1
# KT KV
# A  1    93.75  3.232759  1.00  6.50  1.345380  2.0000  2.0000  2.0000
#    2    31.75  3.527778  2.00  6.25  1.346005  2.2500  2.2500  2.2500
#    2NT  38.00  3.454545  2.00  4.75  0.871377  2.8750  2.8750  2.8750
# A1 1     4.75  2.375000  2.00  2.75  0.375000  2.1875  2.1875  2.1875
#    2NT  12.75  3.187500  2.00  4.25  0.797947  2.9375  2.9375  2.9375
# B  1    25.75  3.218750  1.75  4.50  0.804650  3.0000  3.0000  3.0000
#    2NT   3.75  3.750000  3.75  3.75  0.000000  3.7500  3.7500  3.7500
# C  1    43.50  5.437500  4.75  7.00  0.681795  5.0000  5.0000  5.0000
#    2    11.50  5.750000  5.00  6.50  0.750000  5.3750  5.3750  5.3750
#    2NT  24.25  6.062500  5.25  7.00  0.817294  5.2500  5.2500  5.2500
# D1 1    46.75  3.596154  1.50  5.75  1.215044  2.7500  2.7500  2.7500
# ...

# %%
#phan2
gt = df.groupby('GT')['GT'].agg('count')

# %%
gt.plot.bar()
# Out:
# <AxesSubplot:xlabel='GT'>

# %%
gt.plot.pie()
# Out:
# <AxesSubplot:ylabel='GT'>

# %%
gt.plot.area()
# Out:
# <AxesSubplot:xlabel='GT'>

# %%
#cau22
cau22 = pd.DataFrame (df ,columns=['US_TBM1','US_TBM2','US_TBM3'])

# %%
cau22.describe()
# Out:
#           US_TBM1     US_TBM2    US_TBM3
# count  100.000000  100.000000  100.00000
# mean     2.434480    2.559600    2.67176
# std      0.391203    0.377656    0.29981
# min      1.616000    1.768000    1.91600
# 25%      2.107000    2.223000    2.47300
# 50%      2.480000    2.588000    2.70600
# 75%      2.724000    2.893000    2.87400
# max      3.232000    3.416000    3.31600

# %%
cau3 = df[df['GT'] =='M']
cau3.groupby('DT')['DT'].agg('count')
# Out:
# DT
# 0.0    50
# 1.0     1
# 6.0     1
# Name: DT, dtype: int64

# %%
cau4 = df[(df['GT'] == 'M') & (df['DT'] ==1)]
cau4.groupby('DT')['DT'].agg('count')
# Out:
# DT
# 1.0    1
# Name: DT, dtype: int64

# %%
# phần 3 : trực quan hóa dữ liệu theo nhóm phân loại 

cau31 = df[df['GT']=='F'].groupby(['XL1','XL2','XL3'])[['GT']].count()

# %%
cau31.plot.bar()
# Out:
# <AxesSubplot:xlabel='XL1,XL2,XL3'>

# %%
#Phần 4
df.groupby('T1')['T1'].count().plot()
# Out:
# <AxesSubplot:xlabel='T1'>

# %%
df.loc[(df['T1']<5),'phanlopt1'] ='kem'
df.loc[(df['T1']>=5)&(df['T1']<7),'phanlopt1'] = 'trung binh'
df.loc[(df['T1']>=7)&(df['T1']<8),'phanlopt1'] = 'kha'
df.loc[(df['T1']>=8),'phanlopt1']='gioi'

# %%
df.head(5)
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM2  TBM3  XL1  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.54  7.01    K
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  5.47  5.07    Y
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.38  6.04   TB
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  6.2  ...  5.20  6.88   TB
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  5.5  ...  6.36  6.99    K
#
#      XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT   phanlopt1
# STT
# 1      K    K    2.800    3.016    2.804   0.0         kha
# 2     TB   TB    1.876    2.188    2.028   0.0  trung binh
# 3     TB   TB    2.308    2.152    2.416   1.0  trung binh
# 4     TB    K    2.484    2.080    2.752   0.0  trung binh
# 5     TB    K    2.600    2.544    2.796   0.0  trung binh
#
# [5 rows x 66 columns]

# %%
#3 vẽ biểu đồ đường multiple line cho biến T1 được phân loại bởi biến phanlopt1
dfphanlopt1 = df.groupby(['T1','phanlopt1'])[['T1','phanlopt1']].count()

# %%
unstackphanlopt1 = dfphanlopt1.unstack()

# %%
unstackphanlopt1.head(10)
# Out:
#             T1                     phanlopt1
# phanlopt1 gioi  kem kha trung binh      gioi  kem kha trung binh
# T1
# 2.4        NaN  1.0 NaN        NaN       NaN  1.0 NaN        NaN
# 2.5        NaN  1.0 NaN        NaN       NaN  1.0 NaN        NaN
# 2.6        NaN  1.0 NaN        NaN       NaN  1.0 NaN        NaN
# 2.7        NaN  1.0 NaN        NaN       NaN  1.0 NaN        NaN
# 2.8        NaN  1.0 NaN        NaN       NaN  1.0 NaN        NaN
# 3.0        NaN  2.0 NaN        NaN       NaN  2.0 NaN        NaN
# 3.4        NaN  1.0 NaN        NaN       NaN  1.0 NaN        NaN
# 3.6        NaN  2.0 NaN        NaN       NaN  2.0 NaN        NaN
# 3.7        NaN  1.0 NaN        NaN       NaN  1.0 NaN        NaN
# 3.9        NaN  1.0 NaN        NaN       NaN  1.0 NaN        NaN

# %%
unstackphanlopt1['phanlopt1'].plot(ylabel='Count')
# Out:
# <AxesSubplot:xlabel='T1', ylabel='Count'>

# %%
unstackphanlopt1['phanlopt1'].plot.bar()
# Out:
# <AxesSubplot:xlabel='T1'>
